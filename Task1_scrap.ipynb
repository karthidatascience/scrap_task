# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import pandas as pd

rows=[]
link2_=[]
url='https://www.ashleyfurniture.com/c/furniture/living-room/'
headers={
'authority':
'www.ashleyfurniture.com',
'method':
'GET',
'path':
'/c/furniture/living-room/',
'scheme':
'https',
'accept':
'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
'accept-encoding':
'gzip, deflate, br, zstd',
'accept-language':
'en-US,en;q=0.9',
'cache-control':
'max-age=0',
'cookie':
'optimizely_user_id=f0659889-2e52-41bd-a051-b6e865ed85ac; dwac_8af2abab5fd9f5a4106b3de0a8=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE%3D|dw-only|||USD|false|US%2FEastern|true; cqcid=bcyu2EmkmJAYDrLYdObQrA6saN; cquid=||; sid=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE; dwanonymous_4b223e5821b70d248aeba587a188686c=bcyu2EmkmJAYDrLYdObQrA6saN; dwsgst=eyJraWQiOiIxNzQyNzE0NzAwODcwIiwiYWxnIjoiRVMyNTYifQ..pt9chK2aneJPVqyoTyqp2AeEyalIfaJJRMpva2nHBsoW8GhOda0wj36SJ4jc4S2wJvX-wfKPrheLAwQwZrXYfg; __cq_dnt=0; dw_dnt=0; dwsid=hdxXUBNQAbcL1qFSA_Thrl4hKHl4VbMP24Mehr43touXt1dfVQcd_3sYA6UVmLYtGtaZqyYA7YUeZKAYNiZPjw==; _pxhd=yHaa4uDn9Lxb6DXuNZQ65-a8nl9v4pJQdY5Z47TWm9Ua70XbB5gteWMCk68ugik7KpNDWf9bw6DoNw-0l694CQ==:pKogQ0xziG2afvXt2O46q3/gjgsYokdFneBhjot/RMFuWgDIXuG8TfQnESbHkKqk7RCyAldZV5mceH9besBrtye/k3X3RoMa01EtF--THiI=; rmStore=dmid:false; ConstructorioID_client_id=42116283-0638-413a-981e-53a9de48e552; pxcts=296f4537-1f60-11f0-b674-611e0624c809; _pxvid=282fa50c-1f60-11f0-8825-a746293b6d7c; ConstructorioID_client_id=42116283-0638-413a-981e-53a9de48e552; ConstructorioID_session_id=1; __pxvid=29ccc79a-1f60-11f0-9fb5-ba8fdb6bf831; _gcl_au=1.1.559433805.1745315801; _cs_mk_ga=0.00674482371034002_1745315801830; _axwrt=3835e653-5993-4e08-8f6b-4284288f98ff; _scid=zWRNbk1ivt0SHF702LVAuZ15CeymjbQH; FPID=FPID2.2.F%2FT4amySgiKrH1TR6WoIoFzjjXj8CvZlu5KkB3jeImk%3D.1745315805; FPLC=tyiiLNYNDeWsmdLQJ3%2Fp0yhdfBMmxYl8m8ZMzpyCRg0Qrot06vP0XAKtiSnqszubjXrMOxrc2Gi3SsH2dTZxYa6ICvgywwPqv72n8T3dS7EGDiBOxnF24QlKyJaBRg%3D%3D; __cq_uuid=bcyu2EmkmJAYDrLYdObQrA6saN; __cq_seg=0~0.00!1~0.00!2~0.00!3~0.00!4~0.00!5~0.00!6~0.00!7~0.00!8~0.00!9~0.00; _gid=GA1.2.629797906.1745315807; __pdst=8e2d24ec573c46d79b8aaac5ed852875; smartDash=3adee41c-abf6-4ded-a62d-290629e78348; _fbp=fb.1.1745315809737.50926004775544; _pin_unauth=dWlkPU1qUTNOMlF4Wm1NdE16Um1aQzAwTkRSaExXRXdNRGt0WkdRellqQTJabVZqWlRZNQ; _tt_enable_cookie=1; _ttp=01JSEEVKFY21N8ZGA3BBH0FS4K_.tt.1; _li_dcdm_c=.ashleyfurniture.com; _lc2_fpi=e6202ab56b5a--01jseevpbqf7a5me0ffqaf26wg;
Google Chrome";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
'sec-ch-ua-mobile':
'?0',
'sec-ch-ua-platform':
"Windows",
'sec-fetch-dest':
'document',
'sec-fetch-mode':
'navigate',
'sec-fetch-site':
'same-origin',
'upgrade-insecure-requests':
'1',
'user-agent':
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
}
r=requests.get(url,headers=headers)
soup = BeautifulSoup(r.content,'html.parser')
s1=soup.find_all('div',class_='af-image-text-link-v34-grid af-grid-flex mobile-header-padding desktop-header-padding')
for i in s1:

    s2=i.find_all('div',class_='af-image-text-link-v34-cell')
    for div in s2:
        a_tag = div.find('a')  # Get the first <a> tag inside the div
        if a_tag:
            link1=a_tag.get('href')
            link2='https://www.ashleyfurniture.com'+link1
            print(link1)
            print(link2)
            link2_.append(link2)
            for i in range(30,500,30):
              url1=f'{link2}?start={i}&sz=30'
              print(url1)
              headers={
                    'authority':
                    'www.ashleyfurniture.com',
                    'method':
                    'GET',
                    'path':
                    f'{link1}',
                    'scheme':
                    'https',
                    'accept':
                    'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
                    'accept-encoding':
                    'gzip, deflate, br, zstd',
                    'accept-language':
                    'en-US,en;q=0.9',
                    'cookie':
                    'optimizely_user_id=f0659889-2e52-41bd-a051-b6e865ed85ac; dwac_8af2abab5fd9f5a4106b3de0a8=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE%3D|dw-only|||USD|false|US%2FEastern|true; cqcid=bcyu2EmkmJAYDrLYdObQrA6saN; cquid=||; sid=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE; dwanonymous_4b223e5821b70d248aeba587a188686c=bcyu2EmkmJAYDrLYdObQrA6saN; dwsgst=eyJraWQiOiIxNzQyNzE0NzAwODcwIiwiYWxnIjoiRVMyNTYifQ..pt9chK2aneJPVqyoTyqp2AeEyalIfaJJRMpva2nHBsoW8GhOda0wj36SJ4jc4S2wJvX-wfKPrheLAwQwZrXYfg; __cq_dnt=0; dw_dnt=0; dwsid=hdxXUBNQAbcL1qFSA_Thrl4hKHl4VbMP24Mehr43touXt1dfVQcd_3sYA6UVmLYtGtaZqyYA7YUeZKAYNiZPjw==; _pxhd=yHaa4uDn9Lxb6DXuNZQ65-a8nl9v4pJQdY5Z47TWm9Ua70XbB5gteWMCk68ugik7KpNDWf9bw6DoNw-0l694CQ==:pKogQ0xziG2afvXt2O46q3/gjgsYokdFneBhjot/RMFuWgDIXuG8TfQnESbHkKqk7RCyAldZV5mceH9besBrtye/k3X3RoMa01EtF--THiI=; rmStore=dmid:false; ConstructorioID_client_id=42116283-0638-413a-981e-53a9de48e552; pxcts=296f4537-1f60-11f0-b674-611e0624c809; _pxvid=282fa50c-1f60-11f0-8825-a746293b6d7c; ConstructorioID_client_id=42116283-0638-413a-981e-53a9de48e552; ConstructorioID_session_id=1; __pxvid=29ccc79a-1f60-11f0-9fb5-ba8fdb6bf831; _gcl_au=1.1.559433805.1745315801; _cs_mk_ga=0.00674482371034002_1745315801830; _axwrt=3835e653-5993-4e08-8f6b-4284288f98ff; _scid=zWRNbk1ivt0SHF702LVAuZ15CeymjbQH; FPID=FPID2.2.F%2FT4amySgiKrH1TR6WoIoFzjjXj8CvZlu5KkB3jeIm
Time)&version=202407.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=c6880f90-a5aa-431d-ad5b-88c0415ada93&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0003%3A1%2CC0005%3A1%2CC0001%3A1%2CC0002%3A1%2CC0004%3A1&intType=3&geolocation=IN%3BTN&AwaitingReconsent=false; ax_visitor=%7B%22firstVisitTs%22%3A1745315803813%2C%22lastVisitTs%22%3Anull%2C%22currentVisitStartTs%22%3A1745315803813%2C%22ts%22%3A1745316175670%2C%22visitCount%22%3A1%7D',
                    'priority':
                    'u=0, i',
                    'referer':
                    f'{url}',
                    'sec-ch-ua':
                    '"Google Chrome";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
                    'sec-ch-ua-mobile':
                    '?0',
                    'sec-ch-ua-platform':
                    "Windows",
                    'sec-fetch-dest':
                    'document',
                    'sec-fetch-mode':
                    'navigate',
                    'sec-fetch-site':
                    'same-origin',
                    'sec-fetch-user':
                    '?1',
                    'upgrade-insecure-requests':
                    '1',
                    'user-agent':
                    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'

                }
              r1=requests.get(url1,headers=headers)
              soup1 = BeautifulSoup(r1.content,'html.parser')

              k = soup1.find_all('div', class_="wide-tile-bullets")

              for j in k:
                  a_tag = j.find('a')
                  if a_tag:
                      link3 = a_tag.get('href')
                      aria_label = a_tag.get('aria-label', '')
                      product_name = ''
                      if 'Click to Go to Product:' in aria_label:
                          product_name = aria_label.split('Click to Go to Product:')[-1].strip()
                      print(product_name)
                      print(link3)
                      link3_=link3.split('/')[-1].replace('.html','').strip()
                      print(link3_)

                      url3=f'https://www.ashleyfurniture.com/on/demandware.store/Sites-Ashley-US-Site/default/Product-ProductDetailsJson?sku={link3_}'
                      headers={
                      'authority':
                      'www.ashleyfurniture.com',
                      'method':
                      'GET',
                      'path':
                      f'/on/demandware.store/Sites-Ashley-US-Site/default/Product-ProductDetailsJson?sku={link3_}',
                      'scheme':
                      'https',
                      'accept':
                      '*/*',
                      'accept-encoding':
                      'gzip, deflate, br, zstd',
                      'accept-language':
                      'en-US,en;q=0.9',
                      'cookie':
                      'optimizely_user_id=9c7365a8-2fce-4ba3-a36b-672e8f0ea228; dwac_8af2abab5fd9f5a4106b3de0a8=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE%3D|dw-only|||USD|false|US%2FEastern|true; cqcid=bcyu2EmkmJAYDrLYdObQrA6saN; cquid=||; sid=w7LgVknA9yL0hGXUjTYvmBhPn38ixUWaJNE; dwanonymous_4b223e5821b70d248aeba587a188686c=bcyu2EmkmJAYDrLYdObQrA6saN; dwsgst=eyJraWQiOiIxNzQyNzE0NzAwODcwIiwiYWxnIjoiRVMyNTYifQ..pt9chK2aneJPVqyoTyqp2AeEyalIfaJJRMpva2nHBsoW8GhOda0wj36SJ4jc4S2wJvX-wfKPrheLAwQwZrXYfg; __cq_dnt=0; dw_dnt=0; dwsid=hdxXUBNQAbcL1qFSA_Thrl4hKHl4VbMP24Mehr43touXt1dfVQcd_3sYA6UVmL
lertBoxClosed=2025-04-22T09:59:07.441Z; pixlee_analytics_cookie=%7B%22CURRENT_PIXLEE_USER_ID%22%3A%229704e496-6eb5-f2f5-679b-eba91dc51925%22%7D; pixlee_analytics_cookie_legacy=%7B%22CURRENT_PIXLEE_USER_ID%22%3A%229704e496-6eb5-f2f5-679b-eba91dc51925%22%7D; TTSVID=d0f8cd08-5f36-475a-9cca-bfe315658685; _scid_r=2-RNbk1ivt0SHF702LVAuZ15CeymjbQHk61d_Q; _ga=GA1.2.646378416.1745315805; ttcsid=1745315810833.1.1745316518481; OptanonConsent=isGpcEnabled=0&datestamp=Tue+Apr+22+2025+05%3A08%3A41+GMT-0500+(Central+Daylight+Time)&version=202407.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=c6880f90-a5aa-431d-ad5b-88c0415ada93&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0003%3A1%2CC0005%3A1%2CC0001%3A1%2CC0002%3A1%2CC0004%3A1&intType=3&geolocation=IN%3BTN&AwaitingReconsent=false; ttcsid_CV0TDDBC77U54LNIEO0G=1745315810832.1.1745316530452; ax_visitor=%7B%22firstVisitTs%22%3A1745315803813%2C%22lastVisitTs%22%3Anull%2C%22currentVisitStartTs%22%3A1745315803813%2C%22ts%22%3A1745316546215%2C%22visitCount%22%3A1%7D; _ga_NS8MPLW4LR=GS1.1.1745315805.1.1.1745316547.0.0.1624972535; _ga_YJ4C5QGH4Q=GS1.1.1745315805.1.1.1745316547.0.0.0; _ga_X9DRQWMD18=GS1.1.1745315811.1.1.1745316547.60.0.0; _ga_Q5P9RCE29Z=GS1.1.1745315811.1.1.1745316547.0.0.1299281101; ConstructorioID_session={"sessionId":1,"lastTime":1745316548917}',
                      'priority':
                      'u=1, i',
                      'referer':
                      f'https://www.ashleyfurniture.com/p/altari_sofa/{link3_}.html',
                      'sec-ch-ua':
                      '"Google Chrome";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
                      'sec-ch-ua-mobile':
                      '?0',
                      'sec-ch-ua-platform':
                      "Windows",
                      'sec-fetch-dest':
                      'empty',
                      'sec-fetch-mode':
                      'cors',
                      'sec-fetch-site':
                      'same-origin',
                      'user-agent':
                      'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
                      }
                      r3=requests.get(url3,headers=headers)
                      data = r3.json()
                      # print(data)
                      shortDescription=data['shortDescription']
                      print(shortDescription)
                      longDescription=data['longDescription']
                      print(longDescription)
                      fabricDetails=data['fabricDetails']
                      print(fabricDetails)
                      itemDimFriendlyDesc=data['itemDimFriendlyDesc']
                      print(itemDimFriendlyDesc)
                      additionalDimensions=data['additionalDimensions']
                      print(additionalDimensions)
                      productName=data['productName']
                      print(productName)
                      row_dict = {
                                'url':url,
                              'link2': link2,
                              'url1': url1,
                              'link3': link3,
                              'product_name': product_name,
                              'shortDescription': shortDescription,
                              'longDescription:': longDescription,
                              'fabricDetails': fabricDetails,
                              'itemDimFriendlyDesc':itemDimFriendlyDesc,
                              'additionalDimensions': additionalDimensions,
                              'productName': productName,

                            }
                      rows.append(row_dict)

  result_df = pd.DataFrame(rows)
  result_df.to_excel('task1.xlsx', index=False)
